# %%
import automl

# C'est tout ! Le système fait le reste
data_dest = "/path/to/data"
automl.fit(data_dest)
automl.eval()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 5
#       3 # C'est tout ! Le système fait le reste
#       4 data_dest = "/path/to/data"
# ----> 5 automl.fit(data_dest)
#       6 automl.eval()
#
# AttributeError: module 'automl' has no attribute 'fit'
